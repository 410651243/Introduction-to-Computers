# %% [markdown]
# <a href="https://colab.research.google.com/github/410651243/Introduction-to-Computers/blob/main/week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import pandas_datareader.data as vb
import datetime
start = datetime.datetime(2017,1,1)
end = datetime.datetime(2020,10,17)
#end = datetime.date.today()  #setup the period

# %%
#download the financial data from stooq
sqcl = vb.DataReader("SQ", "stooq", start, end)['Close']
sqcl  #peek at the data
# Out:
# Date
# 2020-10-16    186.35
# 2020-10-15    188.60
# 2020-10-14    187.49
# 2020-10-13    190.47
# 2020-10-12    185.17
#                ...
# 2017-01-09     15.06
# 2017-01-06     15.00
# 2017-01-05     14.56
# 2017-01-04     14.25
# 2017-01-03     13.81
# Name: Close, Length: 955, dtype: float64

# %% [markdown]
# **股價**

# %%
#get the info of the stock close price and describe the distribution
sqcl.min()
# Out:
# 13.81

# %%
sqcl.max()
# Out:
# 190.47

# %%
sqcl.mean()
# Out:
# 62.19631413612566

# %%
sqcl.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Calculate the simple return and plot the return.STAT
sqcl.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 955 entries, 2020-10-16 to 2017-01-03
# Series name: Close
# Non-Null Count  Dtype
# --------------  -----
# 955 non-null    float64
# dtypes: float64(1)
# memory usage: 14.9 KB

# %%
sq = vb.DataReader("SQ", "stooq", start, end)

# %% [markdown]
# **算數報酬**
#
# 1.以2018年1/1至2021年10/15 期間SQUARE股票的交易日收盤價計算算術報酬率，期間日報酬率的平均
#
# 2.2018年1/1至2021年10/15 期間SQUARE股票的交易日收盤價中，前5筆平均算術報酬率為何？
#
# 3.2018年1/1至2021年10/15 期間SQUARE股票的交易日收盤價中，後8筆平均算術報酬率為何？
#
# 4.2018年1/1至2021年10/15 期間SOUARE股票的交易日收盤價中，歷史算術報洲率高點為何？

# %%
sq['simple return']=(sq['Close']/sq['Close'].shift(1)-1)

# %%
sq['simple return'].mean()
# Out:
# -0.0017943763361055018

# %%
sq['simple return'].mean()*251
# Out:
# -0.3373739265655146

# %%
sq['simple return'].head(5).mean()
# Out:
# -0.0014357852545031913

# %%
sq['simple return'].tail(8).mean()
# Out:
# -0.015859710479073974

# %%
sq['simple return'].max()
# Out:
# 0.3998061545917131

# %%
sq['simple return'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **對數報酬**

# %%
import math

# %%
sq['log return']=[math.log(x)for x in ((sq['Close']/sq['Close'].shift(1)))]

# %%
sq['log return'].mean()
# Out:
# -0.0020222461745290363

# %%
sq['log return'].head(5).mean()
# Out:
# -0.01732353041937775

# %%
sq['log return'].tail(8).mean()
# Out:
# -0.01642763335208541

# %%
sq['log return'].min()
# Out:
# -0.146228497623517

# %%
sq['log return'].max()
# Out:
# 0.3363337660286837

# %%
sq['log return'].plot()
# Out:
# <Axes: xlabel='Date'>
